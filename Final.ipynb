# %% [markdown]
# # Speaker Identification and Transcribing Model
#
#
# 1. Making the necessary imports

# %%
import os
import torch
import torchaudio
import numpy as np
from pyannote.audio import Pipeline, Model, Inference
from sklearn.cluster import DBSCAN
from sklearn.metrics.pairwise import cosine_distances
import warnings
from transformers import pipeline
warnings.filterwarnings("ignore")

# Check if CUDA is available
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"The device being used is {device}")

# HuggingFace token
hf = "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"
# Out:
# The device being used is cuda

# %%
# Initialize diarization pipeline
diarization_pipeline = Pipeline.from_pretrained(
    "pyannote/speaker-diarization-3.1",
    use_auth_token=hf
).to(device)

# Initialize embedding model
embedding_model = Inference(
    Model.from_pretrained("pyannote/embedding", use_auth_token=hf).to(device),
    window="whole"
)

# Initialize Whisper ASR model
whisper_pipeline = pipeline(
    "automatic-speech-recognition", 
    model="openai/whisper-medium"
)
# Out:
# INFO:speechbrain.utils.quirks:Applied quirks (see `speechbrain.utils.quirks`): [allow_tf32, disable_jit_profiling]
# INFO:speechbrain.utils.quirks:Excluded quirks specified by the `SB_DISABLE_QUIRKS` environment (comma-separated list): []
# Lightning automatically upgraded your loaded checkpoint from v1.2.7 to v2.4.0. To apply the upgrade to your files permanently, run `python -m pytorch_lightning.utilities.upgrade_checkpoint C:\Users\shoke\.cache\torch\pyannote\models--pyannote--embedding\snapshots\4db4899737a38b2d618bbd74350915aa10293cb2\pytorch_model.bin`
# Lightning automatically upgraded your loaded checkpoint from v1.2.7 to v2.4.0. To apply the upgrade to your files permanently, run `python -m pytorch_lightning.utilities.upgrade_checkpoint C:\Users\shoke\.cache\torch\pyannote\models--pyannote--embedding\snapshots\4db4899737a38b2d618bbd74350915aa10293cb2\pytorch_model.bin`
# Model was trained with pyannote.audio 0.0.1, yours is 3.1.1. Bad things might happen unless you revert pyannote.audio to 0.x.
# Model was trained with torch 1.8.1+cu102, yours is 2.2.1+cu118. Bad things might happen unless you revert torch to 1.x.
# Model was trained with pyannote.audio 0.0.1, yours is 3.1.1. Bad things might happen unless you revert pyannote.audio to 0.x.
# Model was trained with torch 1.8.1+cu102, yours is 2.2.1+cu118. Bad things might happen unless you revert torch to 1.x.

# %%
# List of audio files to process
audio_files = ["./data/sample1.wav", "./data/sample2.wav","./data/john1.wav","./data/sample5.wav","./data/trump1.wav"]

# Perform diarization
diarization_results = []
for audio_file in audio_files:
    waveform, sample_rate = torchaudio.load(audio_file)
    waveform = waveform.to(device)

    diarization = diarization_pipeline({"waveform": waveform, "sample_rate": sample_rate})
    diarization_results.append({"file": audio_file, "diarization": diarization})

# Display results for the first file
for i, file_result in enumerate(diarization_results):
        print(f"\nDiarization results for {file_result['file']}:")
        for turn, _, speaker_label in file_result['diarization'].itertracks(yield_label=True):
            print(f"Segment: {turn.start:.2f}s - {turn.end:.2f}s, Speaker: {speaker_label}")
# Out:
# Diarization results for ./data/sample1.wav:
# Segment: 1.59s - 9.89s, Speaker: SPEAKER_00
# Segment: 10.87s - 11.91s, Speaker: SPEAKER_00
# Segment: 12.06s - 15.46s, Speaker: SPEAKER_00
# Segment: 16.65s - 22.35s, Speaker: SPEAKER_00
# Segment: 23.51s - 29.72s, Speaker: SPEAKER_00
# Segment: 30.59s - 36.80s, Speaker: SPEAKER_00
# Segment: 37.38s - 38.23s, Speaker: SPEAKER_00
# Segment: 111.30s - 113.57s, Speaker: SPEAKER_00
# Segment: 114.34s - 116.15s, Speaker: SPEAKER_00
# Segment: 116.48s - 118.65s, Speaker: SPEAKER_00
# Segment: 120.57s - 122.15s, Speaker: SPEAKER_00
# Segment: 122.32s - 122.79s, Speaker: SPEAKER_00
# Segment: 123.03s - 123.68s, Speaker: SPEAKER_00
#
# Diarization results for ./data/trump1.wav:
# Segment: 0.01s - 1.20s, Speaker: SPEAKER_00
# Segment: 1.66s - 7.19s, Speaker: SPEAKER_00
# Segment: 7.48s - 8.74s, Speaker: SPEAKER_00
# Segment: 9.67s - 15.15s, Speaker: SPEAKER_00
# Segment: 15.98s - 19.06s, Speaker: SPEAKER_00
# Segment: 19.36s - 22.83s, Speaker: SPEAKER_00
# Segment: 23.12s - 24.22s, Speaker: SPEAKER_00
# Segment: 24.92s - 28.23s, Speaker: SPEAKER_00
# Segment: 28.60s - 33.05s, Speaker: SPEAKER_00
# Segment: 33.44s - 35.87s, Speaker: SPEAKER_00
# Segment: 36.02s - 40.55s, Speaker: SPEAKER_00

# %%
# Extract embeddings and speaker information
all_embeddings = []
speaker_info = []

for result in diarization_results:
    audio_file = result['file']
    diarization = result['diarization']
    waveform, sample_rate = torchaudio.load(audio_file)
    waveform = waveform.to(device)

    for turn, _, speaker_label in diarization.itertracks(yield_label=True):
        start_time = turn.start
        end_time = turn.end

        if (end_time - start_time) < 1.0:  # Skip very short segments
            continue

        segment = waveform[:, int(start_time * sample_rate):int(end_time * sample_rate)].cpu()
        embedding = embedding_model({"waveform": segment, "sample_rate": sample_rate})
        embedding = embedding / np.linalg.norm(embedding)

        all_embeddings.append(embedding)
        speaker_info.append({
            'audio_file': audio_file,
            'start_time': start_time,
            'end_time': end_time,
            'local_speaker_label': speaker_label
        })

print(f"Extracted {len(all_embeddings)} embeddings.")
# Out:
# Extracted 188 embeddings.

# %%
embeddings_array = np.vstack(all_embeddings)
cosine_sim_matrix = 1 - cosine_distances(embeddings_array)
distance_matrix = 1 - cosine_sim_matrix

clustering = DBSCAN(eps=0.5, min_samples=2, metric='precomputed')
clustering.fit(distance_matrix)

labels = clustering.labels_

# Assign custom labels
speaker_mapping = {
    0: "Vaibhav",
    1: "Sushmit",
    2: "John",
    3:"S Jaishankar",
    4:"Donald Trump"
}

cluster_to_name = {}
for label in set(labels):
    if label == -1:
        continue  # Skip noise points
    cluster_to_name[label] = speaker_mapping.get(label, f"SPEAKER_{label:02d}")

# Display cluster mapping
print("\nCluster to Name Mapping:")
for cluster, name in cluster_to_name.items():
    print(f"Cluster {cluster}: {name}")

# Display results with global labels
print("\nEmbedding Details with Global Labels:")
for idx, info in enumerate(speaker_info):
    cluster_label = labels[idx]
    global_label = cluster_to_name.get(cluster_label, "Noise") if cluster_label != -1 else "Noise"
    print(f"File: {info['audio_file']}")
    print(f"  Segment: {info['start_time']:.2f}s - {info['end_time']:.2f}s")
    print(f"  Local Label: {info['local_speaker_label']}")
    print(f"  Global Label: {global_label} (Cluster {cluster_label})")
    print()
# Out:
# Cluster to Name Mapping:
# Cluster 0: Vaibhav
# Cluster 1: Sushmit
# Cluster 2: John
# Cluster 3: S Jaishankar
# Cluster 4: Donald Trump
#
# Embedding Details with Global Labels:
# File: ./data/sample1.wav
#   Segment: 1.59s - 9.89s
#   Local Label: SPEAKER_00
#   Global Label: Vaibhav (Cluster 0)
#
# File: ./data/sample1.wav
#   Segment: 10.87s - 11.91s
#   Local Label: SPEAKER_00
#   Global Label: Vaibhav (Cluster 0)
#
# File: ./data/sample1.wav
#   Segment: 12.06s - 15.46s
#   Local Label: SPEAKER_00
#   Global Label: Vaibhav (Cluster 0)
#
# File: ./data/sample1.wav
#   Segment: 16.65s - 22.35s
#   Local Label: SPEAKER_00
#   Global Label: Vaibhav (Cluster 0)
#
# File: ./data/sample1.wav
#   Segment: 23.51s - 29.72s
#   Local Label: SPEAKER_00
#   Global Label: Vaibhav (Cluster 0)
#
# File: ./data/sample1.wav
#   Segment: 30.59s - 36.80s
#   Local Label: SPEAKER_00
#   Global Label: Vaibhav (Cluster 0)
#
# File: ./data/sample1.wav
#   Segment: 39.43s - 45.22s
#   Local Label: SPEAKER_00
#   Global Label: Vaibhav (Cluster 0)
#
# File: ./data/sample1.wav
#   Segment: 45.32s - 46.78s
#   Local Label: SPEAKER_00
#   Global Label: Vaibhav (Cluster 0)
#
# File: ./data/sample1.wav
#   Segment: 48.65s - 59.14s
#   Local Label: SPEAKER_00
#   Global Label: Vaibhav (Cluster 0)
#
# File: ./data/sample1.wav
#   Segment: 62.88s - 66.27s
#   Local Label: SPEAKER_00
#   Global Label: Vaibhav (Cluster 0)
#
# File: ./data/sample1.wav
#   Segment: 67.05s - 71.57s
#   Local Label: SPEAKER_00
#   Global Label: Vaibhav (Cluster 0)
#
# File: ./data/sample1.wav
#   Segment: 73.79s - 84.25s
#   Local Label: SPEAKER_00
#   Global Label: Vaibhav (Cluster 0)
#
# File: ./data/sample1.wav
#   Segment: 85.07s - 86.24s
#   Local Label: SPEAKER_00
#   Global Label: Noise (Cluster -1)
#
# File: ./data/sample1.wav
#   Segment: 88.28s - 91.47s
#   Local Label: SPEAKER_00
#   Global Label: Vaibhav (Cluster 0)
#
# File: ./data/sample1.wav
#   Segment: 91.62s - 93.47s
#   Local Label: SPEAKER_00
#   Global Label: Vaibhav (Cluster 0)
#
# File: ./data/sample1.wav
#   Segment: 94.66s - 98.70s
#   Local Label: SPEAKER_00
#   Global Label: Vaibhav (Cluster 0)
#
# File: ./data/sample1.wav
#   Segment: 100.45s - 108.90s
#   Local Label: SPEAKER_00
#   Global Label: Vaibhav (Cluster 0)
#
# File: ./data/sample1.wav
#   Segment: 110.86s - 118.90s
#   Local Label: SPEAKER_00
#   Global Label: Vaibhav (Cluster 0)
#
# File: ./data/sample1.wav
#   Segment: 119.77s - 128.28s
#   Local Label: SPEAKER_00
#   Global Label: Vaibhav (Cluster 0)
#
# File: ./data/sample1.wav
#   Segment: 128.85s - 130.69s
#   Local Label: SPEAKER_00
#   Global Label: Vaibhav (Cluster 0)
#
# File: ./data/sample1.wav
#   Segment: 131.98s - 135.08s
#   Local Label: SPEAKER_00
#   Global Label: Vaibhav (Cluster 0)
#
# File: ./data/sample1.wav
#   Segment: 136.95s - 147.00s
#   Local Label: SPEAKER_00
#   Global Label: Vaibhav (Cluster 0)
#
# File: ./data/sample1.wav
#   Segment: 147.87s - 152.47s
#   Local Label: SPEAKER_00
#   Global Label: Vaibhav (Cluster 0)
#
# File: ./data/sample1.wav
#   Segment: 152.74s - 154.68s
#   Local Label: SPEAKER_00
#   Global Label: Vaibhav (Cluster 0)
#
# File: ./data/sample1.wav
#   Segment: 155.14s - 157.67s
#   Local Label: SPEAKER_00
#   Global Label: Vaibhav (Cluster 0)
#
# File: ./data/sample1.wav
#   Segment: 158.33s - 161.86s
#   Local Label: SPEAKER_00
#   Global Label: Vaibhav (Cluster 0)
#
# File: ./data/sample1.wav
#   Segment: 165.81s - 169.01s
#   Local Label: SPEAKER_00
#   Global Label: Vaibhav (Cluster 0)
#
# File: ./data/sample2.wav
#   Segment: 0.01s - 7.11s
#   Local Label: SPEAKER_01
#   Global Label: Sushmit (Cluster 1)
#
# File: ./data/sample2.wav
#   Segment: 7.50s - 10.48s
#   Local Label: SPEAKER_01
#   Global Label: Sushmit (Cluster 1)
#
# File: ./data/sample2.wav
#   Segment: 11.25s - 19.23s
#   Local Label: SPEAKER_00
#   Global Label: Vaibhav (Cluster 0)
#
# File: ./data/sample2.wav
#   Segment: 19.67s - 22.45s
#   Local Label: SPEAKER_00
#   Global Label: Vaibhav (Cluster 0)
#
# File: ./data/sample2.wav
#   Segment: 23.17s - 32.22s
#   Local Label: SPEAKER_01
#   Global Label: Sushmit (Cluster 1)
#
# File: ./data/sample2.wav
#   Segment: 32.64s - 35.14s
#   Local Label: SPEAKER_01
#   Global Label: Noise (Cluster -1)
#
# File: ./data/sample2.wav
#   Segment: 35.29s - 36.71s
#   Local Label: SPEAKER_01
#   Global Label: Sushmit (Cluster 1)
#
# File: ./data/sample2.wav
#   Segment: 36.80s - 38.84s
#   Local Label: SPEAKER_01
#   Global Label: Sushmit (Cluster 1)
#
# File: ./data/sample2.wav
#   Segment: 39.69s - 45.03s
#   Local Label: SPEAKER_00
#   Global Label: Vaibhav (Cluster 0)
#
# File: ./data/sample2.wav
#   Segment: 45.42s - 48.17s
#   Local Label: SPEAKER_00
#   Global Label: Vaibhav (Cluster 0)
#
# File: ./data/sample2.wav
#   Segment: 48.58s - 50.60s
#   Local Label: SPEAKER_00
#   Global Label: Vaibhav (Cluster 0)
#
# File: ./data/sample2.wav
#   Segment: 50.93s - 53.90s
#   Local Label: SPEAKER_00
#   Global Label: Vaibhav (Cluster 0)
#
# File: ./data/sample2.wav
#   Segment: 54.42s - 57.75s
#   Local Label: SPEAKER_00
#   Global Label: Vaibhav (Cluster 0)
#
# File: ./data/sample2.wav
#   Segment: 58.41s - 66.46s
#   Local Label: SPEAKER_00
#   Global Label: Vaibhav (Cluster 0)
#
# File: ./data/sample2.wav
#   Segment: 66.94s - 76.22s
#   Local Label: SPEAKER_01
#   Global Label: Sushmit (Cluster 1)
#
# File: ./data/sample2.wav
#   Segment: 76.71s - 81.76s
#   Local Label: SPEAKER_01
#   Global Label: Sushmit (Cluster 1)
#
# File: ./data/sample2.wav
#   Segment: 82.10s - 85.68s
#   Local Label: SPEAKER_01
#   Global Label: Sushmit (Cluster 1)
#
# File: ./data/sample2.wav
#   Segment: 86.78s - 90.65s
#   Local Label: SPEAKER_00
#   Global Label: Vaibhav (Cluster 0)
#
# File: ./data/sample2.wav
#   Segment: 91.08s - 94.52s
#   Local Label: SPEAKER_00
#   Global Label: Vaibhav (Cluster 0)
#
# File: ./data/sample2.wav
#   Segment: 94.86s - 97.28s
#   Local Label: SPEAKER_00
#   Global Label: Vaibhav (Cluster 0)
#
# File: ./data/sample2.wav
#   Segment: 97.43s - 101.37s
#   Local Label: SPEAKER_00
#   Global Label: Vaibhav (Cluster 0)
#
# File: ./data/sample2.wav
#   Segment: 101.59s - 103.93s
#   Local Label: SPEAKER_00
#   Global Label: Vaibhav (Cluster 0)
#
# File: ./data/sample2.wav
#   Segment: 104.71s - 106.19s
#   Local Label: SPEAKER_00
#   Global Label: Noise (Cluster -1)
#
# File: ./data/sample2.wav
#   Segment: 106.66s - 111.30s
#   Local Label: SPEAKER_00
#   Global Label: Vaibhav (Cluster 0)
#
# File: ./data/sample2.wav
#   Segment: 112.22s - 117.72s
#   Local Label: SPEAKER_01
#   Global Label: Sushmit (Cluster 1)
#
# File: ./data/sample2.wav
#   Segment: 118.17s - 125.53s
#   Local Label: SPEAKER_01
#   Global Label: Sushmit (Cluster 1)
#
# File: ./data/sample2.wav
#   Segment: 125.75s - 127.55s
#   Local Label: SPEAKER_01
#   Global Label: Sushmit (Cluster 1)
#
# File: ./data/sample2.wav
#   Segment: 128.07s - 134.35s
#   Local Label: SPEAKER_01
#   Global Label: Sushmit (Cluster 1)
#
# File: ./data/sample2.wav
#   Segment: 134.80s - 137.75s
#   Local Label: SPEAKER_01
#   Global Label: Sushmit (Cluster 1)
#
# File: ./data/sample2.wav
#   Segment: 138.79s - 141.45s
#   Local Label: SPEAKER_00
#   Global Label: Vaibhav (Cluster 0)
#
# File: ./data/sample2.wav
#   Segment: 141.86s - 144.24s
#   Local Label: SPEAKER_00
#   Global Label: Vaibhav (Cluster 0)
#
# File: ./data/sample2.wav
#   Segment: 144.68s - 147.44s
#   Local Label: SPEAKER_00
#   Global Label: Vaibhav (Cluster 0)
#
# File: ./data/sample2.wav
#   Segment: 147.58s - 150.98s
#   Local Label: SPEAKER_00
#   Global Label: Vaibhav (Cluster 0)
#
# File: ./data/sample2.wav
#   Segment: 151.49s - 154.07s
#   Local Label: SPEAKER_00
#   Global Label: Vaibhav (Cluster 0)
#
# File: ./data/sample2.wav
#   Segment: 154.64s - 158.36s
#   Local Label: SPEAKER_00
#   Global Label: Vaibhav (Cluster 0)
#
# File: ./data/sample2.wav
#   Segment: 158.87s - 163.64s
#   Local Label: SPEAKER_00
#   Global Label: Vaibhav (Cluster 0)
#
# File: ./data/sample2.wav
#   Segment: 164.46s - 169.40s
#   Local Label: SPEAKER_00
#   Global Label: Vaibhav (Cluster 0)
#
# File: ./data/sample2.wav
#   Segment: 170.21s - 177.12s
#   Local Label: SPEAKER_01
#   Global Label: Sushmit (Cluster 1)
#
# File: ./data/sample2.wav
#   Segment: 177.90s - 180.84s
#   Local Label: SPEAKER_01
#   Global Label: Sushmit (Cluster 1)
#
# File: ./data/sample2.wav
#   Segment: 181.13s - 182.28s
#   Local Label: SPEAKER_01
#   Global Label: Sushmit (Cluster 1)
#
# File: ./data/sample2.wav
#   Segment: 182.72s - 184.80s
#   Local Label: SPEAKER_01
#   Global Label: Sushmit (Cluster 1)
#
# File: ./data/sample2.wav
#   Segment: 185.17s - 186.38s
#   Local Label: SPEAKER_01
#   Global Label: Noise (Cluster -1)
#
# File: ./data/sample2.wav
#   Segment: 186.87s - 190.77s
#   Local Label: SPEAKER_01
#   Global Label: Sushmit (Cluster 1)
#
# File: ./data/sample2.wav
#   Segment: 191.30s - 193.40s
#   Local Label: SPEAKER_01
#   Global Label: Sushmit (Cluster 1)
#
# File: ./data/sample2.wav
#   Segment: 194.07s - 196.71s
#   Local Label: SPEAKER_01
#   Global Label: Sushmit (Cluster 1)
#
# File: ./data/sample2.wav
#   Segment: 197.73s - 203.08s
#   Local Label: SPEAKER_00
#   Global Label: Vaibhav (Cluster 0)
#
# File: ./data/sample2.wav
#   Segment: 203.40s - 204.90s
#   Local Label: SPEAKER_00
#   Global Label: Vaibhav (Cluster 0)
#
# File: ./data/sample2.wav
#   Segment: 205.02s - 212.50s
#   Local Label: SPEAKER_00
#   Global Label: Vaibhav (Cluster 0)
#
# File: ./data/sample2.wav
#   Segment: 212.72s - 216.90s
#   Local Label: SPEAKER_00
#   Global Label: Vaibhav (Cluster 0)
#
# File: ./data/sample2.wav
#   Segment: 217.36s - 220.04s
#   Local Label: SPEAKER_00
#   Global Label: Vaibhav (Cluster 0)
#
# File: ./data/sample2.wav
#   Segment: 220.57s - 226.02s
#   Local Label: SPEAKER_00
#   Global Label: Vaibhav (Cluster 0)
#
# File: ./data/sample2.wav
#   Segment: 226.39s - 228.48s
#   Local Label: SPEAKER_00
#   Global Label: Vaibhav (Cluster 0)
#
# File: ./data/sample2.wav
#   Segment: 228.70s - 233.68s
#   Local Label: SPEAKER_00
#   Global Label: Vaibhav (Cluster 0)
#
# File: ./data/sample2.wav
#   Segment: 234.25s - 242.50s
#   Local Label: SPEAKER_01
#   Global Label: Sushmit (Cluster 1)
#
# File: ./data/sample2.wav
#   Segment: 243.01s - 244.49s
#   Local Label: SPEAKER_01
#   Global Label: Noise (Cluster -1)
#
# File: ./data/sample2.wav
#   Segment: 244.64s - 257.92s
#   Local Label: SPEAKER_01
#   Global Label: Sushmit (Cluster 1)
#
# File: ./data/sample2.wav
#   Segment: 259.97s - 264.29s
#   Local Label: SPEAKER_01
#   Global Label: Sushmit (Cluster 1)
#
# File: ./data/sample2.wav
#   Segment: 264.80s - 266.48s
#   Local Label: SPEAKER_01
#   Global Label: Sushmit (Cluster 1)
#
# File: ./data/sample2.wav
#   Segment: 266.90s - 269.48s
#   Local Label: SPEAKER_01
#   Global Label: Sushmit (Cluster 1)
#
# File: ./data/sample2.wav
#   Segment: 270.04s - 273.13s
#   Local Label: SPEAKER_01
#   Global Label: Sushmit (Cluster 1)
#
# File: ./data/sample2.wav
#   Segment: 273.78s - 276.48s
#   Local Label: SPEAKER_01
#   Global Label: Sushmit (Cluster 1)
#
# File: ./data/sample2.wav
#   Segment: 277.12s - 278.50s
#   Local Label: SPEAKER_01
#   Global Label: Noise (Cluster -1)
#
# File: ./data/sample2.wav
#   Segment: 279.01s - 282.72s
#   Local Label: SPEAKER_01
#   Global Label: Sushmit (Cluster 1)
#
# File: ./data/sample2.wav
#   Segment: 282.89s - 284.12s
#   Local Label: SPEAKER_01
#   Global Label: Noise (Cluster -1)
#
# File: ./data/sample2.wav
#   Segment: 284.88s - 286.61s
#   Local Label: SPEAKER_01
#   Global Label: Sushmit (Cluster 1)
#
# File: ./data/sample2.wav
#   Segment: 286.80s - 289.97s
#   Local Label: SPEAKER_01
#   Global Label: Sushmit (Cluster 1)
#
# File: ./data/sample2.wav
#   Segment: 290.43s - 294.90s
#   Local Label: SPEAKER_01
#   Global Label: Sushmit (Cluster 1)
#
# File: ./data/john1.wav
#   Segment: 1.35s - 8.09s
#   Local Label: SPEAKER_00
#   Global Label: John (Cluster 2)
#
# File: ./data/john1.wav
#   Segment: 8.33s - 11.32s
#   Local Label: SPEAKER_00
#   Global Label: John (Cluster 2)
#
# File: ./data/john1.wav
#   Segment: 11.62s - 33.37s
#   Local Label: SPEAKER_00
#   Global Label: John (Cluster 2)
#
# File: ./data/john1.wav
#   Segment: 33.88s - 36.63s
#   Local Label: SPEAKER_00
#   Global Label: John (Cluster 2)
#
# File: ./data/john1.wav
#   Segment: 36.99s - 41.20s
#   Local Label: SPEAKER_00
#   Global Label: John (Cluster 2)
#
# File: ./data/john1.wav
#   Segment: 41.84s - 44.85s
#   Local Label: SPEAKER_00
#   Global Label: John (Cluster 2)
#
# File: ./data/john1.wav
#   Segment: 45.70s - 52.20s
#   Local Label: SPEAKER_01
#   Global Label: Vaibhav (Cluster 0)
#
# File: ./data/john1.wav
#   Segment: 53.54s - 54.68s
#   Local Label: SPEAKER_01
#   Global Label: Vaibhav (Cluster 0)
#
# File: ./data/john1.wav
#   Segment: 55.24s - 56.90s
#   Local Label: SPEAKER_01
#   Global Label: Vaibhav (Cluster 0)
#
# File: ./data/john1.wav
#   Segment: 57.36s - 59.50s
#   Local Label: SPEAKER_01
#   Global Label: Vaibhav (Cluster 0)
#
# File: ./data/john1.wav
#   Segment: 60.09s - 63.44s
#   Local Label: SPEAKER_01
#   Global Label: Vaibhav (Cluster 0)
#
# File: ./data/john1.wav
#   Segment: 63.85s - 65.88s
#   Local Label: SPEAKER_01
#   Global Label: Vaibhav (Cluster 0)
#
# File: ./data/john1.wav
#   Segment: 67.29s - 69.55s
#   Local Label: SPEAKER_01
#   Global Label: Vaibhav (Cluster 0)
#
# File: ./data/john1.wav
#   Segment: 70.13s - 73.08s
#   Local Label: SPEAKER_01
#   Global Label: Vaibhav (Cluster 0)
#
# File: ./data/john1.wav
#   Segment: 73.56s - 75.03s
#   Local Label: SPEAKER_01
#   Global Label: Vaibhav (Cluster 0)
#
# File: ./data/john1.wav
#   Segment: 75.39s - 78.29s
#   Local Label: SPEAKER_01
#   Global Label: Vaibhav (Cluster 0)
#
# File: ./data/john1.wav
#   Segment: 78.79s - 80.52s
#   Local Label: SPEAKER_01
#   Global Label: Vaibhav (Cluster 0)
#
# File: ./data/john1.wav
#   Segment: 80.81s - 83.00s
#   Local Label: SPEAKER_01
#   Global Label: Vaibhav (Cluster 0)
#
# File: ./data/john1.wav
#   Segment: 83.95s - 85.48s
#   Local Label: SPEAKER_00
#   Global Label: John (Cluster 2)
#
# File: ./data/john1.wav
#   Segment: 86.65s - 88.31s
#   Local Label: SPEAKER_00
#   Global Label: John (Cluster 2)
#
# File: ./data/john1.wav
#   Segment: 88.50s - 91.26s
#   Local Label: SPEAKER_00
#   Global Label: John (Cluster 2)
#
# File: ./data/john1.wav
#   Segment: 92.03s - 94.03s
#   Local Label: SPEAKER_00
#   Global Label: John (Cluster 2)
#
# File: ./data/john1.wav
#   Segment: 94.37s - 95.39s
#   Local Label: SPEAKER_00
#   Global Label: Noise (Cluster -1)
#
# File: ./data/john1.wav
#   Segment: 95.65s - 98.97s
#   Local Label: SPEAKER_00
#   Global Label: John (Cluster 2)
#
# File: ./data/john1.wav
#   Segment: 99.47s - 104.17s
#   Local Label: SPEAKER_00
#   Global Label: John (Cluster 2)
#
# File: ./data/john1.wav
#   Segment: 104.39s - 105.58s
#   Local Label: SPEAKER_00
#   Global Label: John (Cluster 2)
#
# File: ./data/john1.wav
#   Segment: 105.97s - 108.58s
#   Local Label: SPEAKER_00
#   Global Label: John (Cluster 2)
#
# File: ./data/john1.wav
#   Segment: 110.23s - 111.52s
#   Local Label: SPEAKER_00
#   Global Label: John (Cluster 2)
#
# File: ./data/john1.wav
#   Segment: 111.62s - 113.54s
#   Local Label: SPEAKER_00
#   Global Label: John (Cluster 2)
#
# File: ./data/john1.wav
#   Segment: 113.93s - 115.34s
#   Local Label: SPEAKER_00
#   Global Label: Noise (Cluster -1)
#
# File: ./data/john1.wav
#   Segment: 115.56s - 117.53s
#   Local Label: SPEAKER_00
#   Global Label: John (Cluster 2)
#
# File: ./data/john1.wav
#   Segment: 118.45s - 120.28s
#   Local Label: SPEAKER_00
#   Global Label: John (Cluster 2)
#
# File: ./data/john1.wav
#   Segment: 121.11s - 127.33s
#   Local Label: SPEAKER_01
#   Global Label: Vaibhav (Cluster 0)
#
# File: ./data/john1.wav
#   Segment: 128.11s - 131.64s
#   Local Label: SPEAKER_01
#   Global Label: Vaibhav (Cluster 0)
#
# File: ./data/john1.wav
#   Segment: 131.94s - 135.90s
#   Local Label: SPEAKER_01
#   Global Label: Vaibhav (Cluster 0)
#
# File: ./data/john1.wav
#   Segment: 136.39s - 139.55s
#   Local Label: SPEAKER_01
#   Global Label: Vaibhav (Cluster 0)
#
# File: ./data/john1.wav
#   Segment: 139.96s - 144.81s
#   Local Label: SPEAKER_01
#   Global Label: Vaibhav (Cluster 0)
#
# File: ./data/john1.wav
#   Segment: 145.49s - 148.28s
#   Local Label: SPEAKER_01
#   Global Label: Vaibhav (Cluster 0)
#
# File: ./data/john1.wav
#   Segment: 148.80s - 153.64s
#   Local Label: SPEAKER_01
#   Global Label: Vaibhav (Cluster 0)
#
# File: ./data/john1.wav
#   Segment: 153.90s - 155.31s
#   Local Label: SPEAKER_01
#   Global Label: Vaibhav (Cluster 0)
#
# File: ./data/john1.wav
#   Segment: 155.78s - 157.51s
#   Local Label: SPEAKER_01
#   Global Label: Vaibhav (Cluster 0)
#
# File: ./data/john1.wav
#   Segment: 158.41s - 160.59s
#   Local Label: SPEAKER_01
#   Global Label: Vaibhav (Cluster 0)
#
# File: ./data/john1.wav
#   Segment: 161.15s - 166.17s
#   Local Label: SPEAKER_01
#   Global Label: Vaibhav (Cluster 0)
#
# File: ./data/john1.wav
#   Segment: 166.29s - 168.53s
#   Local Label: SPEAKER_01
#   Global Label: Vaibhav (Cluster 0)
#
# File: ./data/john1.wav
#   Segment: 169.94s - 177.17s
#   Local Label: SPEAKER_00
#   Global Label: John (Cluster 2)
#
# File: ./data/john1.wav
#   Segment: 177.48s - 178.80s
#   Local Label: SPEAKER_00
#   Global Label: John (Cluster 2)
#
# File: ./data/john1.wav
#   Segment: 179.07s - 182.25s
#   Local Label: SPEAKER_00
#   Global Label: John (Cluster 2)
#
# File: ./data/john1.wav
#   Segment: 182.74s - 189.07s
#   Local Label: SPEAKER_00
#   Global Label: John (Cluster 2)
#
# File: ./data/sample5.wav
#   Segment: 1.06s - 3.78s
#   Local Label: SPEAKER_00
#   Global Label: S Jaishankar (Cluster 3)
#
# File: ./data/sample5.wav
#   Segment: 5.25s - 7.11s
#   Local Label: SPEAKER_00
#   Global Label: Noise (Cluster -1)
#
# File: ./data/sample5.wav
#   Segment: 8.24s - 11.45s
#   Local Label: SPEAKER_00
#   Global Label: S Jaishankar (Cluster 3)
#
# File: ./data/sample5.wav
#   Segment: 11.79s - 13.42s
#   Local Label: SPEAKER_00
#   Global Label: Noise (Cluster -1)
#
# File: ./data/sample5.wav
#   Segment: 13.78s - 16.36s
#   Local Label: SPEAKER_00
#   Global Label: S Jaishankar (Cluster 3)
#
# File: ./data/sample5.wav
#   Segment: 19.14s - 21.15s
#   Local Label: SPEAKER_00
#   Global Label: S Jaishankar (Cluster 3)
#
# File: ./data/sample5.wav
#   Segment: 21.84s - 23.96s
#   Local Label: SPEAKER_00
#   Global Label: S Jaishankar (Cluster 3)
#
# File: ./data/sample5.wav
#   Segment: 25.81s - 27.29s
#   Local Label: SPEAKER_00
#   Global Label: Noise (Cluster -1)
#
# File: ./data/sample5.wav
#   Segment: 28.04s - 30.48s
#   Local Label: SPEAKER_00
#   Global Label: S Jaishankar (Cluster 3)
#
# File: ./data/sample5.wav
#   Segment: 31.47s - 33.56s
#   Local Label: SPEAKER_00
#   Global Label: S Jaishankar (Cluster 3)
#
# File: ./data/sample5.wav
#   Segment: 34.46s - 37.72s
#   Local Label: SPEAKER_00
#   Global Label: S Jaishankar (Cluster 3)
#
# File: ./data/sample5.wav
#   Segment: 46.88s - 48.48s
#   Local Label: SPEAKER_00
#   Global Label: S Jaishankar (Cluster 3)
#
# File: ./data/sample5.wav
#   Segment: 48.94s - 50.81s
#   Local Label: SPEAKER_00
#   Global Label: Noise (Cluster -1)
#
# File: ./data/sample5.wav
#   Segment: 51.23s - 52.98s
#   Local Label: SPEAKER_00
#   Global Label: S Jaishankar (Cluster 3)
#
# File: ./data/sample5.wav
#   Segment: 55.32s - 56.49s
#   Local Label: SPEAKER_00
#   Global Label: Noise (Cluster -1)
#
# File: ./data/sample5.wav
#   Segment: 57.46s - 58.97s
#   Local Label: SPEAKER_00
#   Global Label: S Jaishankar (Cluster 3)
#
# File: ./data/sample5.wav
#   Segment: 60.47s - 61.54s
#   Local Label: SPEAKER_00
#   Global Label: Noise (Cluster -1)
#
# File: ./data/sample5.wav
#   Segment: 61.89s - 64.34s
#   Local Label: SPEAKER_00
#   Global Label: S Jaishankar (Cluster 3)
#
# File: ./data/sample5.wav
#   Segment: 64.58s - 66.02s
#   Local Label: SPEAKER_00
#   Global Label: Noise (Cluster -1)
#
# File: ./data/sample5.wav
#   Segment: 67.36s - 70.37s
#   Local Label: SPEAKER_00
#   Global Label: S Jaishankar (Cluster 3)
#
# File: ./data/sample5.wav
#   Segment: 70.74s - 73.69s
#   Local Label: SPEAKER_00
#   Global Label: S Jaishankar (Cluster 3)
#
# File: ./data/sample5.wav
#   Segment: 77.68s - 79.79s
#   Local Label: SPEAKER_00
#   Global Label: Noise (Cluster -1)
#
# File: ./data/sample5.wav
#   Segment: 80.62s - 81.98s
#   Local Label: SPEAKER_00
#   Global Label: Noise (Cluster -1)
#
# File: ./data/sample5.wav
#   Segment: 82.11s - 88.29s
#   Local Label: SPEAKER_00
#   Global Label: S Jaishankar (Cluster 3)
#
# File: ./data/sample5.wav
#   Segment: 90.79s - 92.54s
#   Local Label: SPEAKER_00
#   Global Label: Noise (Cluster -1)
#
# File: ./data/sample5.wav
#   Segment: 93.03s - 94.98s
#   Local Label: SPEAKER_00
#   Global Label: Noise (Cluster -1)
#
# File: ./data/sample5.wav
#   Segment: 95.70s - 97.02s
#   Local Label: SPEAKER_00
#   Global Label: S Jaishankar (Cluster 3)
#
# File: ./data/sample5.wav
#   Segment: 97.55s - 99.84s
#   Local Label: SPEAKER_00
#   Global Label: Noise (Cluster -1)
#
# File: ./data/sample5.wav
#   Segment: 100.16s - 104.27s
#   Local Label: SPEAKER_00
#   Global Label: S Jaishankar (Cluster 3)
#
# File: ./data/sample5.wav
#   Segment: 105.15s - 106.66s
#   Local Label: SPEAKER_00
#   Global Label: Noise (Cluster -1)
#
# File: ./data/sample5.wav
#   Segment: 108.21s - 110.26s
#   Local Label: SPEAKER_00
#   Global Label: Noise (Cluster -1)
#
# File: ./data/sample5.wav
#   Segment: 111.30s - 113.57s
#   Local Label: SPEAKER_00
#   Global Label: Noise (Cluster -1)
#
# File: ./data/sample5.wav
#   Segment: 114.34s - 116.15s
#   Local Label: SPEAKER_00
#   Global Label: Noise (Cluster -1)
#
# File: ./data/sample5.wav
#   Segment: 116.48s - 118.65s
#   Local Label: SPEAKER_00
#   Global Label: S Jaishankar (Cluster 3)
#
# File: ./data/sample5.wav
#   Segment: 120.57s - 122.15s
#   Local Label: SPEAKER_00
#   Global Label: S Jaishankar (Cluster 3)
#
# File: ./data/trump1.wav
#   Segment: 0.01s - 1.20s
#   Local Label: SPEAKER_00
#   Global Label: Noise (Cluster -1)
#
# File: ./data/trump1.wav
#   Segment: 1.66s - 7.19s
#   Local Label: SPEAKER_00
#   Global Label: Donald Trump (Cluster 4)
#
# File: ./data/trump1.wav
#   Segment: 7.48s - 8.74s
#   Local Label: SPEAKER_00
#   Global Label: Noise (Cluster -1)
#
# File: ./data/trump1.wav
#   Segment: 9.67s - 15.15s
#   Local Label: SPEAKER_00
#   Global Label: Donald Trump (Cluster 4)
#
# File: ./data/trump1.wav
#   Segment: 15.98s - 19.06s
#   Local Label: SPEAKER_00
#   Global Label: Donald Trump (Cluster 4)
#
# File: ./data/trump1.wav
#   Segment: 19.36s - 22.83s
#   Local Label: SPEAKER_00
#   Global Label: Donald Trump (Cluster 4)
#
# File: ./data/trump1.wav
#   Segment: 23.12s - 24.22s
#   Local Label: SPEAKER_00
#   Global Label: Noise (Cluster -1)
#
# File: ./data/trump1.wav
#   Segment: 24.92s - 28.23s
#   Local Label: SPEAKER_00
#   Global Label: Donald Trump (Cluster 4)
#
# File: ./data/trump1.wav
#   Segment: 28.60s - 33.05s
#   Local Label: SPEAKER_00
#   Global Label: Donald Trump (Cluster 4)
#
# File: ./data/trump1.wav
#   Segment: 33.44s - 35.87s
#   Local Label: SPEAKER_00
#   Global Label: Donald Trump (Cluster 4)
#
# File: ./data/trump1.wav
#   Segment: 36.02s - 40.55s
#   Local Label: SPEAKER_00
#   Global Label: Noise (Cluster -1)

# %%
# Save embeddings, labels, and cluster-to-name mapping
np.savez_compressed("known_embeddings.npz", 
                    embeddings=all_embeddings, 
                    speaker_info=speaker_info, 
                    labels=labels, 
                    cluster_to_name=cluster_to_name)
print("Known embeddings saved to 'known_embeddings.npz'.")
# Out:
# Known embeddings saved to 'known_embeddings.npz'.

# %%
known_data = np.load("known_embeddings.npz", allow_pickle=True)
known_embeddings = known_data['embeddings']
known_labels = known_data['labels']
cluster_to_name = dict(known_data['cluster_to_name'].item())

# Load new audio file
new_audio_file = "./data/john2.wav"
waveform, sample_rate = torchaudio.load(new_audio_file)
waveform = waveform.to(device)

# Perform diarization
diarization = diarization_pipeline({"waveform": waveform, "sample_rate": sample_rate})

# Transcribe with speaker labels
transcriptions = []
for turn, _, speaker_label in diarization.itertracks(yield_label=True):
    start_time = turn.start
    end_time = turn.end
    duration = end_time - start_time

    if duration < 1.0:
        continue  # Skip short segments

    start_idx = int(start_time * sample_rate)
    end_idx = int(end_time * sample_rate)
    segment = waveform[:, start_idx:end_idx].cpu()
    embedding = embedding_model({"waveform": segment, "sample_rate": sample_rate})
    embedding = embedding / np.linalg.norm(embedding)

    # Match with known speakers
    similarities = 1 - cosine_distances([embedding], known_embeddings).flatten()
    matched_label = known_labels[np.argmax(similarities)]
    speaker_name = cluster_to_name.get(matched_label, f"SPEAKER_{matched_label:02d}")

    # Transcribe the segment
    transcription = whisper_pipeline(segment.squeeze().numpy())
    transcriptions.append({
        'speaker_name': speaker_name,
        'start_time': start_time,
        'end_time': end_time,
        'text': transcription['text']
    })

# Display transcriptions
transcript_text = ""
for segment in transcriptions:
    transcript_line = (
        f"[{segment['speaker_name']}] {segment['text']} "
        f"({segment['start_time']:.2f}s - {segment['end_time']:.2f}s)"
    )
    print(transcript_line)
    transcript_text += transcript_line + "\n"

# Save transcript to a text file
transcript_file = os.path.splitext(new_audio_file)[0] + "_transcript.txt"
with open(transcript_file, "w", encoding="utf-8") as file:
    file.write(transcript_text)

print(f"\nTranscript saved to {transcript_file}")
# Out:
# [John]  But Abhinash was not able to complete his sentence. He felt such an intense pleasure in abusing Binoi that he was incapable of even pretending to be anxious on his account. (1.10s - 10.98s)
# [John]  In less than no time, all the important members of Kura's party came in turn. (11.45s - 15.49s)
# [John]  And when they were all gathered, a heated discussion soon started on the subject of Benoit's Kanda. (15.75s - 21.06s)
# [John]  The majority of them had only one comment to make, and it was that this present affair was no matter for surprise, because they had all of them again and again noticed signs of weakness and hesitation in Benoit's character. (21.55s - 34.13s)
# [John]  They declared that Benoit had never surrendered himself wholeheartedly to their party. (35.25s - 39.38s)
# [John]  Many of them said they had always felt how intolerable was the way in which he had tried. (39.74s - 44.52s)
# [John]  Somehow or other from the very beginning in which he had tried somehow or other (44.66s - 49.94s)
# [Vaibhav]  But they merely laughed at me and ended by taking me for a feeble-minded fool. (52.59s - 57.21s)
# [Vaibhav]  They exonerated me. (57.31s - 58.92s)
# [Vaibhav]  explaining that they had asked for whatever they had and that it had been bound to happen. (59.30s - 64.61s)
# [Vaibhav]  Finally, they warned me that I was becoming dangerous. (65.03s - 67.70s)
# [Vaibhav]  and that they would have to lock me up in a madhouse if I didn't shut up. (68.19s - 71.84s)
# [Vaibhav]  That hurt me terribly. (72.42s - 73.68s)
# [Vaibhav]  Sorrow compressed my heart and I felt I would die and then well (74.05s - 77.87s)
# [Vaibhav]  It was morning already. (79.57s - 80.84s)
# [Vaibhav]  the sun had risen but it had (80.96s - 82.69s)
# [Vaibhav]  Wars after fight. (83.01s - 84.56s)
# [Vaibhav]  I found myself in my old armchair. (85.19s - 87.22s)
# [John]  where everyone else had kept himself at a proper distance out of respect. (88.19s - 91.96s)
# [John]  Benoit had forced himself from Gora (92.23s - 94.12s)
# [John]  and made out that he was in terms of such intimacy (94.32s - 96.97s)
# [John]  that he appeared to be aloof from the rest of them. (97.19s - 99.45s)
# [John]  and equal in importance to Gora himself. (99.69s - 101.83s)
# [John]  because Gora was fond of him. (102.06s - 103.93s)
# [John]  They had all of them done their best to tolerate this extraordinary arrogance, and this was the deplorable sequel to that kind of unchecked vanity. (104.00s - 111.99s)
# [Vaibhav]  Nothing really, I don't know Lisa. You see, I used to know a strict, stern man who would go down on his knees before his daughter and (113.29s - 122.01s)
# [Vaibhav]  Kiss her hands and feet. (122.33s - 123.64s)
# [Vaibhav]  He just couldn't admire her enough. (124.02s - 125.90s)
# [Vaibhav]  She could spend the night dancing and her father would stand in the same spot for 5 hours without taking his eyes off her. (126.31s - 132.01s)
# [John]  They said, we may not be so well educated as Binoy Babu and we have not such great intelligence, but at least we have all along followed one principle, we don't say one thing and think another. (133.01s - 144.00s)
#
# Transcript saved to ./data/john2_transcript.txt
